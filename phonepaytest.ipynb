# %%
import os
import json
import pandas as pd
import mysql.connector
import streamlit as st
from streamlit_option_menu import option_menu
import plotly.express as px
import altair as alt

def agg_insurance():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/aggregated/insurance/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"transaction_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['transactionData']:
                    trans_name=i['name']
                    count=i['paymentInstruments'][0]['count']
                    amount=i['paymentInstruments'][0]['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["transaction_name"].append(trans_name)
                    column["count"].append(count)
                    column["amount"].append(amount)
    agg_ins_data=pd.DataFrame(column)
    agg_ins_data["state"].unique()
    agg_ins_data["state"]=agg_ins_data["state"].str.replace("-"," ")
    agg_ins_data["state"]=agg_ins_data["state"].str.title()
    agg_ins_data["state"]=agg_ins_data["state"].str.replace("&","and")

    agg_ins_table='''CREATE TABLE if not exists aggregated_insurance(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    Transaction_Name varchar(50),
                                                    Count bigint,
                                                    Amount bigint
                                                    )'''
    cursor.execute(agg_ins_table)
    connection.commit() 

    for index, row in agg_ins_data.iterrows():
        insert_query = '''INSERT INTO aggregated_insurance(State,Year,Quarter,Transaction_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['transaction_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()

    return agg_ins_data

def agg_trans():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/aggregated/transaction/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"transaction_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['transactionData']:
                    name=i['name']
                    count=i['paymentInstruments'][0]['count']
                    amount=i['paymentInstruments'][0]['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["transaction_name"].append(name)
                    column["count"].append(count)
                    column["amount"].append(amount)
    agg_trans_data=pd.DataFrame(column)
    agg_trans_data["state"].unique()
    agg_trans_data["state"]=agg_trans_data["state"].str.replace("-"," ")
    agg_trans_data["state"]=agg_trans_data["state"].str.title()
    agg_trans_data["state"]=agg_trans_data["state"].str.replace("&","and")
   

    agg_trans_table='''CREATE TABLE if not exists aggregated_transaction(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    Transaction_Name varchar(150),
                                                    Count bigint,
                                                    Amount bigint
                                                    )'''
    cursor.execute(agg_trans_table)
    connection.commit()

    for index, row in agg_trans_data.iterrows():
        insert_query = '''INSERT INTO aggregated_transaction(State,Year,Quarter,
                                                            Transaction_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['transaction_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()

    return agg_trans_data

def agg_user():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    
    path2="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/aggregated/user/country/india/state/"
    user_list=os.listdir(path2)
    columns={"state":[],"year":[],"quarter":[],"brand_name":[],"count":[],"percentage":[]}
    for state in user_list:
        state_link=path2+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                file=years_link+jsonfile
                data=open(file,"r")
                B=json.load(data)
                try:
                    for i in B['data']['usersByDevice']:
                        brand=i['brand']
                        count=i['count']
                        percentage=i['percentage']

                        columns["state"].append(state)
                        columns["year"].append(years)
                        columns["quarter"].append(int(jsonfile.strip(".json")))
                        columns["brand_name"].append(brand)
                        columns["count"].append(count)
                        columns["percentage"].append(percentage)
                except:
                    pass
    user_data=pd.DataFrame(columns)
    user_data["state"].unique()
    user_data["state"]=user_data["state"].str.replace("-"," ")
    user_data["state"]=user_data["state"].str.title()
    user_data["state"]=user_data["state"].str.replace("&","and")
    
    agg_user_table='''CREATE TABLE if not exists aggregated_user(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    Brand_Name varchar(150),
                                                    Count bigint,
                                                    Percentage FLOAT
                                                    )'''
    cursor.execute(agg_user_table)
    connection.commit()

    for index, row in user_data.iterrows():
        insert_query = '''INSERT INTO aggregated_user(State,Year,Quarter,
                                                            Brand_Name,Count,Percentage)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['brand_name'],
            row['count'],
            row['percentage']
        ))

    connection.commit()

    return user_data    


def map_insurance():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/map/insurance/hover/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"district_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['hoverDataList']:
                    dis_name=i['name']
                    count=i['metric'][0]['count']
                    amount=i['metric'][0]['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["district_name"].append(dis_name)
                    column["count"].append(count)
                    column["amount"].append(amount)
    map_ins_data=pd.DataFrame(column)
    map_ins_data["state"].unique()
    map_ins_data["state"]=map_ins_data["state"].str.replace("-"," ")
    map_ins_data["state"]=map_ins_data["state"].str.title()
    map_ins_data["state"]=map_ins_data["state"].str.replace("&","and")

    map_ins_table='''CREATE TABLE if not exists map_insurance(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    District_Name varchar(150),
                                                    Count bigint,
                                                    Amount bigint
                                                    )'''
    cursor.execute(map_ins_table)
    connection.commit()

    for index, row in map_ins_data.iterrows():
        insert_query = '''INSERT INTO map_insurance(State,Year,Quarter,
                                                            District_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['district_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()

    return map_ins_data

def map_trans():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/map/transaction/hover/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"district_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['hoverDataList']:
                    name=i['name']
                    count=i['metric'][0]['count']
                    amount=i['metric'][0]['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["district_name"].append(name)
                    column["count"].append(count)
                    column["amount"].append(amount)
    map_trans_data=pd.DataFrame(column)
    map_trans_data["state"].unique()
    map_trans_data["state"]=map_trans_data["state"].str.replace("-"," ")
    map_trans_data["state"]=map_trans_data["state"].str.title()
    map_trans_data["state"]=map_trans_data["state"].str.replace("&","and")
    
    map_trans_table='''CREATE TABLE if not exists map_transaction(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    District_Name varchar(150),
                                                    Count bigint,
                                                    Amount decimal(65,10)
                                                    )'''
    cursor.execute(map_trans_table)
    connection.commit()

    for index, row in map_trans_data.iterrows():
        insert_query = '''INSERT INTO map_transaction(State,Year,Quarter,
                                                            District_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['district_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()
    return map_trans_data

def map_users():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/map/user/hover/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"district_name":[],"registered_users":[],"app_opens":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['hoverData'].items():
                    dist_name=i[0]
                    reg_users=i[1]['registeredUsers']
                    app_opens=i[1]['appOpens']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["district_name"].append(dist_name)
                    column["registered_users"].append(reg_users)
                    column["app_opens"].append(app_opens)

    map_users_data=pd.DataFrame(column)
    map_users_data["state"].unique()
    map_users_data["state"]=map_users_data["state"].str.replace("-"," ")
    map_users_data["state"]=map_users_data["state"].str.title()
    map_users_data["state"]=map_users_data["state"].str.replace("&","and")

    map_users_table='''CREATE TABLE if not exists map_users(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    District_Name varchar(150),
                                                    Registered_Users bigint,
                                                    App_Opens bigint
                                                    )'''
    cursor.execute(map_users_table)
    connection.commit()
    

    for index, row in map_users_data.iterrows():
        insert_query = '''INSERT INTO map_users(State,Year,Quarter,
                                                            District_Name,Registered_Users,App_Opens)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['district_name'],
            row['registered_users'],
            row['app_opens']
        ))

    connection.commit()

    return map_users_data

def top_insurance():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()

    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/top/insurance/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"district_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['districts']:
                    entity_name=i['entityName']
                    count=i['metric']['count']
                    amount=i['metric']['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column['district_name'].append(entity_name)
                    column['count'].append(count)
                    column['amount'].append(amount)

    top_ins_data=pd.DataFrame(column)
    top_ins_data["state"].unique()
    top_ins_data["state"]=top_ins_data["state"].str.replace("-"," ")
    top_ins_data["state"]=top_ins_data["state"].str.title()
    top_ins_data["state"]=top_ins_data["state"].str.replace("&","and")

    top_ins_table='''CREATE TABLE if not exists top_insurance(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    District_Name varchar(50),
                                                    Count bigint,
                                                    Amount bigint
                                                    )'''
    cursor.execute(top_ins_table)
    connection.commit() 

    for index, row in top_ins_data.iterrows():
        insert_query = '''INSERT INTO top_insurance(State,Year,Quarter,District_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['district_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()
    return top_ins_data

def top_trans():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()

    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/top/transaction/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"district_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)

                for i in A['data']['districts']:
                    entity_name=i['entityName']
                    count=i['metric']['count']
                    amount=i['metric']['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column['district_name'].append(entity_name)
                    column['count'].append(count)
                    column['amount'].append(amount)

    top_trans_data=pd.DataFrame(column)
    top_trans_data["state"].unique()
    top_trans_data["state"]=top_trans_data["state"].str.replace("-"," ")
    top_trans_data["state"]=top_trans_data["state"].str.title()
    top_trans_data["state"]=top_trans_data["state"].str.replace("&","and")

    top_trans_table='''CREATE TABLE if not exists top_transaction(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    District_Name varchar(150),
                                                    Count bigint,
                                                    Amount decimal(65,10)
                                                    )'''
    cursor.execute(top_trans_table)
    connection.commit()

    for index, row in top_trans_data.iterrows():
        insert_query = '''INSERT INTO top_transaction(State,Year,Quarter,
                                                            District_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['district_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()
    return top_trans_data

def top_users():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/top/user/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"pincodes":[],"registered_users":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['pincodes']:
                    name=i['name']
                    reg_users=i['registeredUsers']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["pincodes"].append(name)
                    column["registered_users"].append(reg_users)
    top_users_data=pd.DataFrame(column)
    top_users_data["state"].unique()
    top_users_data["state"]=top_users_data["state"].str.replace("-"," ")
    top_users_data["state"]=top_users_data["state"].str.title()
    top_users_data["state"]=top_users_data["state"].str.replace("&","and")

    top_users_table='''CREATE TABLE if not exists top_users(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    Pincodes bigint,
                                                    Registered_Users bigint
                                                    )'''
    cursor.execute(top_users_table)
    connection.commit()
    

    for index, row in top_users_data.iterrows():
        insert_query = '''INSERT INTO top_users(State,Year,Quarter,
                                                            Pincodes,Registered_Users)
                          VALUES (%s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['pincodes'],
            row['registered_users']
            
        ))
    connection.commit()
    
    return top_users_data

# %%
connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
cursor=connection.cursor()
#agg_ins_df
cursor.execute("SELECT * FROM aggregated_insurance")
table1=cursor.fetchall()
agg_ins_df=pd.DataFrame(table1,columns=("State","Year","Quarter","Transaction_Name","Count","Amount"))
connection.commit()
#agg_trans_df
cursor.execute("SELECT * FROM aggregated_transaction")
table2=cursor.fetchall()
agg_trans_df=pd.DataFrame(table2,columns=("State","Year","Quarter","Transaction_Name",
                                          "Count","Amount"))
connection.commit()
#agg_user_df
cursor.execute("SELECT * FROM aggregated_user")
table3=cursor.fetchall()
agg_user_df=pd.DataFrame(table3,columns=("State","Year","Quarter","Brand_Name","Count","Percentage"))
connection.commit()


#map_ins_df
cursor.execute("SELECT * FROM map_insurance")
table4=cursor.fetchall()
map_ins_df=pd.DataFrame(table4,columns=("State","Year","Quarter","District_Name","Count","Amount"))
connection.commit()
#map_trans_df
cursor.execute("SELECT * FROM map_transaction")
table5=cursor.fetchall()
map_trans_df=pd.DataFrame(table5,columns=("State","Year","Quarter","District_Name","Count","Amount"))
connection.commit()
#map_users_df
cursor.execute("SELECT * FROM map_users")
table6=cursor.fetchall()
map_users_df=pd.DataFrame(table6,columns=("State","Year","Quarter","District_Name","Registered_Users","App_Opens"))
connection.commit()

#top_ins_df
cursor.execute("SELECT * FROM top_insurance")
table7=cursor.fetchall()
top_ins_df=pd.DataFrame(table7,columns=("State","Year","Quarter","District_Name","Count","Amount"))
connection.commit()
#top_trans_df
cursor.execute("SELECT * FROM top_transaction")
table8=cursor.fetchall()
top_trans_df=pd.DataFrame(table8,columns=("State","Year","Quarter","District_Name","Count","Amount"))
connection.commit()
#top_users_df
cursor.execute("SELECT * FROM top_users")
table9=cursor.fetchall()
top_users_df=pd.DataFrame(table9,columns=("State","Year","Quarter","Pincodes","Registered_Users"))
connection.commit()

# %%
def map_insurance():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/map/insurance/hover/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"district_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['hoverDataList']:
                    dis_name=i['name']
                    count=i['metric'][0]['count']
                    amount=i['metric'][0]['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["district_name"].append(dis_name)
                    column["count"].append(count)
                    column["amount"].append(amount)
    map_ins_data=pd.DataFrame(column)
    map_ins_data["state"].unique()
    map_ins_data["state"]=map_ins_data["state"].str.replace("-"," ")
    map_ins_data["state"]=map_ins_data["state"].str.title()
    map_ins_data["state"]=map_ins_data["state"].str.replace("&","and")

    map_ins_table='''CREATE TABLE if not exists map_insurance(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    District_Name varchar(150),
                                                    Count bigint,
                                                    Amount bigint
                                                    )'''
    cursor.execute(map_ins_table)
    connection.commit()

    for index, row in map_ins_data.iterrows():
        insert_query = '''INSERT INTO map_insurance(State,Year,Quarter,
                                                            District_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['district_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()

    return map_ins_data

# %%
import os
import json
import pandas as pd
import mysql.connector

# %%
connection = mysql.connector.connect(
    user='root',
    password='mysql@123',
    database='Phonepay',
    host='localhost'
)
cursor=connection.cursor()

path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/map/insurance/hover/country/india/state/"
path_list=os.listdir(path)
column={"state":[],"year":[],"quarter":[],"district_name":[],"count":[],"amount":[]}
for state in path_list:
    state_link=path+state+"/"
    state_list=os.listdir(state_link)
    for years in state_list:
        years_link=state_link+years+"/"
        years_list=os.listdir(years_link)
        for jsonfile in years_list:
            files=years_link+jsonfile
            data=open(files,"r")
            A=json.load(data)
            for i in A['data']['hoverDataList']:
                district_name = i['district_name']
                print(district_name)
# Out:
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 795.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 565.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 281.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 35, 'amount': 13651.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 1448.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 13, 'amount': 17734.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 109, 'amount': 137494.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 2747.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 48, 'amount': 63978.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 164, 'amount': 167044.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 13, 'amount': 13244.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 28, 'amount': 45311.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 105, 'amount': 121104.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 15089.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 33, 'amount': 50997.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 182, 'amount': 223699.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 15, 'amount': 30539.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 81, 'amount': 182061.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 632, 'amount': 800758.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 44, 'amount': 73561.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 48, 'amount': 85229.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 692, 'amount': 982206.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 28, 'amount': 63852.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 45, 'amount': 90403.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 430, 'amount': 633029.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 26, 'amount': 56308.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 70, 'amount': 129013.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 535, 'amount': 687813.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 38, 'amount': 85640.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 112, 'amount': 224198.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 750, 'amount': 1114857.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 39, 'amount': 102155.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 85, 'amount': 178969.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 872, 'amount': 1172083.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 47, 'amount': 88146.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 56, 'amount': 109742.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 670, 'amount': 1060976.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 42, 'amount': 62677.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 77, 'amount': 133536.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 682, 'amount': 1052324.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 36, 'amount': 65285.0}]}
# {'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 95, 'amount': 156995.0}]}
# {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 1006, 'amount': 1504528.0}]}
# {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 44, 'amount': 96298.0}]}
# {'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 1913, 'amount': 352220.0}]}
# {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 536, 'amount': 107046.0}]}
# {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 931, 'amount': 176423.0}]}
# {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 893, 'amount': 166029.0}]}
# {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 3504, 'amount': 614212.0}]}
# {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 847, 'amount': 161709.0}]}
# {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 2739, 'amount': 485777.0}]}
# {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1978, 'amount': 343002.0}]}
# {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 1074, 'amount': 202289.0}]}
# {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 825, 'amount': 158720.0}]}
# {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 2228, 'amount': 395099.0}]}
# {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 1938, 'amount': 344326.0}]}
# {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count':
0}]}
# {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 2593, 'amount': 3257610.0}]}
# {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1270, 'amount': 1573445.0}]}
# {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 6720, 'amount': 7779967.0}]}
# {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 2137, 'amount': 2552054.0}]}
# {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1934, 'amount': 2719786.0}]}
# {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1892, 'amount': 2559169.0}]}
# {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2314, 'amount': 3113617.0}]}
# {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1318, 'amount': 1720753.0}]}
# {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 3729, 'amount': 5145111.0}]}
# {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 4431, 'amount': 5271211.0}]}
# {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 5529, 'amount': 6149431.0}]}
# {'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 4450, 'amount': 5856052.0}]}
# {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1294, 'amount': 1623449.0}]}
# {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 2733, 'amount': 3658896.0}]}
# {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1373, 'amount': 1680979.0}]}
# {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 7636, 'amount': 9911879.0}]}
# {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 2400, 'amount': 2848596.0}]}
# {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 2425, 'amount': 3710468.0}]}
# {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 2261, 'amount': 2993022.0}]}
# {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2623, 'amount': 3513389.0}]}
# {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1810, 'amount': 2859172.0}]}
# {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 4641, 'amount': 6166050.0}]}
# {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 5199, 'amount': 6244165.0}]}
# {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 5484, 'amount': 6977122.0}]}
# {'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 4069, 'amount': 5915626.0}]}
# {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1100, 'amount': 1628429.0}]}
# {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 2461, 'amount': 3621734.0}]}
# {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1104, 'amount': 1619607.0}]}
# {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 6752, 'amount': 9502319.0}]}
# {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1437, 'amount': 2188369.0}]}
# {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1565, 'amount': 2882540.0}]}
# {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1509, 'amount': 2235497.0}]}
# {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2196, 'amount': 3370241.0}]}
# {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1208, 'amount': 2088411.0}]}
# {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 3284, 'amount': 5677174.0}]}
# {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 3542, 'amount': 4957590.0}]}
# {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 4693, 'amount': 6275818.0}]}
# {'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 3690, 'amount': 5519480.0}]}
# {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1083, 'amount': 1556225.0}]}
# {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 2468, 'amount': 3679371.0}]}
# {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1227, 'amount': 1530183.0}]}
# {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 7000, 'amount': 8910217.0}]}
# {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1311, 'amount': 1880405.0}]}
# {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1688, 'amount': 3027497.0}]}
# {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1652, 'amount': 2426306.0}]}
# {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2140, 'amount': 3383512.0}]}
# {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1473, 'amount': 2483871.0}]}
# {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 3756, 'amount': 5988173.0}]}
# {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 3725, 'amount': 5015442.0}]}
# {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 5163, 'amount': 6666796.0}]}
# {'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 4157, 'amount': 5720660.0}]}
# {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1308, 'amount': 1724487.0}]}
# {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 3082, 'amount': 3962298.0}]}
# {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1274, 'amount': 1526422.0}]}
# {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 8972, 'amount': 11107138.0}]}
# {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1695, 'amount': 2170370.0}]}
# {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1947, 'amount': 3392196.0}]}
# {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1900, 'amount': 2732465.0}]}
# {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2308, 'amount': 3162591.0}]}
# {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1723, 'amount': 2310997.0}]}
# {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 3993, 'amount': 6350318.0}]}
# {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 4604, 'amount': 5810698.0}]}
# {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 6187, 'amount': 7831756.0}]}
# {'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 4294, 'amount': 6404501.0}]}
# {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1327, 'amount': 1851290.0}]}
# {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 2739, 'amount': 3968074.0}]}
# {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1350, 'amount': 1745449.0}]}
# {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 8787, 'amount': 12027284.0}]}
# {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1561, 'amount': 2357325.0}]}
# {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 2143, 'amount': 3651525.0}]}
# {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1923, 'amount': 2738253.0}]}
# {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2198, 'amount': 3630998.0}]}
# {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1829, 'amount': 3161720.0}]}
# {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 4025, 'amount': 7322967.0}]}
# {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 4354, 'amount': 6154821.0}]}
# {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 5268, 'amount': 7328216.0}]}
# {'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount':
0}]}
# {'name': 'siang district', 'metric': [{'type': 'TOTAL', 'count': 8, 'amount': 25817.0}]}
# {'name': 'lower siang district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 14716.0}]}
# {'name': 'kra daadi district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 2861.0}]}
# {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 39, 'amount': 92295.0}]}
# {'name': 'pakke kessang district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 9380.0}]}
# {'name': 'dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 1273.0}]}
# {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 53, 'amount': 140810.0}]}
# {'name': 'shi yomi district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 56.0}]}
# {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 33, 'amount': 62867.0}]}
# {'name': 'upper subansiri district', 'metric': [{'type': 'TOTAL', 'count': 7, 'amount': 6741.0}]}
# {'name': 'east kameng district', 'metric': [{'type': 'TOTAL', 'count': 11, 'amount': 18432.0}]}
# {'name': 'lohit district', 'metric': [{'type': 'TOTAL', 'count': 35, 'amount': 74057.0}]}
# {'name': 'lepa rada district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 11158.0}]}
# {'name': 'tawang district', 'metric': [{'type': 'TOTAL', 'count': 32, 'amount': 117810.0}]}
# {'name': 'namsai district', 'metric': [{'type': 'TOTAL', 'count': 25, 'amount': 52176.0}]}
# {'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 17, 'amount': 32562.0}]}
# {'name': 'lower subansiri district', 'metric': [{'type': 'TOTAL', 'count': 18, 'amount': 52453.0}]}
# {'name': 'longding district', 'metric': [{'type': 'TOTAL', 'count': 11, 'amount': 38902.0}]}
# {'name': 'west siang district', 'metric': [{'type': 'TOTAL', 'count': 26, 'amount': 77049.0}]}
# {'name': 'upper siang district', 'metric': [{'type': 'TOTAL', 'count': 13, 'amount': 45923.0}]}
# {'name': 'tirap district', 'metric': [{'type': 'TOTAL', 'count': 20, 'amount': 42058.0}]}
# {'name': 'papum pare district', 'metric': [{'type': 'TOTAL', 'count': 214, 'amount': 609907.0}]}
# {'name': 'kurung kumey district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 11687.0}]}
# {'name': 'anjaw district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 1257.0}]}
# {'name': 'siang district', 'metric': [{'type': 'TOTAL', 'count': 6, 'amount': 22077.0}]}
# {'name': 'lower siang district', 'metric': [{'type': 'TOTAL', 'count': 11, 'amount': 24273.0}]}
# {'name': 'kra daadi district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 56.0}]}
# {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 58, 'amount': 150506.0}]}
# {'name': 'pakke kessang district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 323.0}]}
# {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 58, 'amount': 148766.0}]}
# {'name': 'shi yomi district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 7170.0}]}
# {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 45, 'amount': 131785.0}]}
# {'name': 'upper subansiri district', 'metric': [{'type': 'TOTAL', 'count': 9, 'amount': 15828.0}]}
# {'name': 'east kameng district', 'metric': [{'type': 'TOTAL', 'count': 12, 'amount': 38909.0}]}
# {'name': 'lohit district', 'metric': [{'type': 'TOTAL', 'count': 22, 'amount': 48743.0}]}
# {'name': 'lepa rada district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 1470.0}]}
# {'name': 'tawang district', 'metric': [{'type': 'TOTAL', 'count': 43, 'amount': 177062.0}]}
# {'name': 'namsai district', 'metric': [{'type': 'TOTAL', 'count': 14, 'amount': 68709.0}]}
# {'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 29, 'amount': 51944.0}]}
# {'name': 'lower subansiri district', 'metric': [{'type': 'TOTAL', 'count': 17, 'amount': 50690.0}]}
# {'name': 'longding district', 'metric': [{'type': 'TOTAL', 'count': 6, 'amount': 11281.0}]}
# {'name': 'west siang district', 'metric': [{'type': 'TOTAL', 'count': 27, 'amount': 85810.0}]}
# {'name': 'kamle district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 1461.0}]}
# {'name': 'upper siang district', 'metric': [{'type': 'TOTAL', 'count': 13, 'amount': 43078.0}]}
# {'name': 'tirap district', 'metric': [{'type': 'TOTAL', 'count': 21, 'amount': 70549.0}]}
# {'name': 'papum pare district', 'metric': [{'type': 'TOTAL', 'count': 261, 'amount': 767297.0}]}
# {'name': 'kurung kumey district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 36.0}]}
# {'name': 'anjaw district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 7504.0}]}
# {'name': 'siang district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 7411.0}]}
# {'name': 'lower siang district', 'metric': [{'type': 'TOTAL', 'count': 6, 'amount': 33183.0}]}
# {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 48, 'amount': 182270.0}]}
# {'name': 'pakke kessang district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 3561.0}]}
# {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 87, 'amount': 278705.0}]}
# {'name': 'shi yomi district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 7321.0}]}
# {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 49, 'amount': 134410.0}]}
# ...
# {'name': 'purba bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 1284, 'amount': 1606058.0}]}
# {'name': 'uttar dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 543, 'amount': 668379.0}]}
# {'name': 'kalimpong district', 'metric': [{'type': 'TOTAL', 'count': 59, 'amount': 145818.0}]}
# {'name': 'murshidabad district', 'metric': [{'type': 'TOTAL', 'count': 1079, 'amount': 1403809.0}]}
# {'name': 'paschim medinipur district', 'metric': [{'type': 'TOTAL', 'count': 1273, 'amount': 1512137.0}]}
# {'name': 'dakshin dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 276, 'amount': 365524.0}]}
# {'name': 'jalpaiguri district', 'metric': [{'type': 'TOTAL', 'count': 587, 'amount': 790267.0}]}
# {'name': 'purulia district', 'metric': [{'type': 'TOTAL', 'count': 438, 'amount': 651866.0}]}
# {'name': 'north twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 6379, 'amount': 8088304.0}]}
# {'name': 'bankura district', 'metric': [{'type': 'TOTAL', 'count':
0}]}
# {'name': 'purba bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 2444, 'amount': 3247192.0}]}
# {'name': 'uttar dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 916, 'amount': 1333587.0}]}
# {'name': 'kalimpong district', 'metric': [{'type': 'TOTAL', 'count': 63, 'amount': 121675.0}]}
# {'name': 'murshidabad district', 'metric': [{'type': 'TOTAL', 'count': 1706, 'amount': 2303518.0}]}
# {'name': 'paschim medinipur district', 'metric': [{'type': 'TOTAL', 'count': 2108, 'amount': 3021797.0}]}
# {'name': 'dakshin dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 433, 'amount': 532754.0}]}
# {'name': 'jalpaiguri district', 'metric': [{'type': 'TOTAL', 'count': 1024, 'amount': 1511512.0}]}
# {'name': 'purulia district', 'metric': [{'type': 'TOTAL', 'count': 768, 'amount': 1218487.0}]}
# {'name': 'north twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 11653, 'amount': 15397844.0}]}
# {'name': 'bankura district', 'metric': [{'type': 'TOTAL', 'count': 957, 'amount': 1267409.0}]}
# {'name': 'jhargram district', 'metric': [{'type': 'TOTAL', 'count': 215, 'amount': 287530.0}]}
# {'name': 'howrah district', 'metric': [{'type': 'TOTAL', 'count': 3960, 'amount': 4940209.0}]}
# {'name': 'hooghly district', 'metric': [{'type': 'TOTAL', 'count': 3336, 'amount': 4705529.0}]}
# {'name': 'kolkata district', 'metric': [{'type': 'TOTAL', 'count': 10667, 'amount': 12579074.0}]}
# {'name': 'koch bihar district', 'metric': [{'type': 'TOTAL', 'count': 925, 'amount': 1174482.0}]}
# {'name': 'alipurduar district', 'metric': [{'type': 'TOTAL', 'count': 589, 'amount': 870892.0}]}
# {'name': 'paschim bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 3285, 'amount': 4337285.0}]}
# {'name': 'nadia district', 'metric': [{'type': 'TOTAL', 'count': 2037, 'amount': 2869837.0}]}
# {'name': 'birbhum district', 'metric': [{'type': 'TOTAL', 'count': 853, 'amount': 1129904.0}]}
# {'name': 'purba medinipur district', 'metric': [{'type': 'TOTAL', 'count': 1663, 'amount': 2203067.0}]}
# {'name': 'maldah district', 'metric': [{'type': 'TOTAL', 'count': 2131, 'amount': 2771850.0}]}
# {'name': 'darjiling district', 'metric': [{'type': 'TOTAL', 'count': 2298, 'amount': 3188462.0}]}
# {'name': 'south twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 5415, 'amount': 6996283.0}]}
# {'name': 'purba bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 2666, 'amount': 3814764.0}]}
# {'name': 'uttar dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 1086, 'amount': 1639258.0}]}
# {'name': 'kalimpong district', 'metric': [{'type': 'TOTAL', 'count': 126, 'amount': 301521.0}]}
# {'name': 'murshidabad district', 'metric': [{'type': 'TOTAL', 'count': 2371, 'amount': 3017303.0}]}
# {'name': 'paschim medinipur district', 'metric': [{'type': 'TOTAL', 'count': 3442, 'amount': 4688055.0}]}
# {'name': 'dakshin dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 563, 'amount': 801958.0}]}
# {'name': 'jalpaiguri district', 'metric': [{'type': 'TOTAL', 'count': 1331, 'amount': 2021880.0}]}
# {'name': 'purulia district', 'metric': [{'type': 'TOTAL', 'count': 976, 'amount': 1408299.0}]}
# {'name': 'north twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 13483, 'amount': 19211808.0}]}
# {'name': 'bankura district', 'metric': [{'type': 'TOTAL', 'count': 1307, 'amount': 1781715.0}]}
# {'name': 'jhargram district', 'metric': [{'type': 'TOTAL', 'count': 279, 'amount': 506882.0}]}
# {'name': 'howrah district', 'metric': [{'type': 'TOTAL', 'count': 5201, 'amount': 6655473.0}]}
# {'name': 'hooghly district', 'metric': [{'type': 'TOTAL', 'count': 4025, 'amount': 5665468.0}]}
# {'name': 'kolkata district', 'metric': [{'type': 'TOTAL', 'count': 12306, 'amount': 16022532.0}]}
# {'name': 'koch bihar district', 'metric': [{'type': 'TOTAL', 'count': 1171, 'amount': 1553342.0}]}
# {'name': 'alipurduar district', 'metric': [{'type': 'TOTAL', 'count': 766, 'amount': 1278792.0}]}
# {'name': 'paschim bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 4095, 'amount': 5823988.0}]}
# {'name': 'nadia district', 'metric': [{'type': 'TOTAL', 'count': 2786, 'amount': 4012958.0}]}
# {'name': 'birbhum district', 'metric': [{'type': 'TOTAL', 'count': 1162, 'amount': 1720043.0}]}
# {'name': 'purba medinipur district', 'metric': [{'type': 'TOTAL', 'count': 2507, 'amount': 3400040.0}]}
# {'name': 'maldah district', 'metric': [{'type': 'TOTAL', 'count': 2886, 'amount': 3998317.0}]}
# {'name': 'darjiling district', 'metric': [{'type': 'TOTAL', 'count': 2762, 'amount': 4044883.0}]}

# %%
pip install --upgrade nbformat
