# %%
import os
import json
import pandas as pd
import mysql.connector
import streamlit as st
from streamlit_option_menu import option_menu
import plotly.express as px
import altair as alt

def agg_insurance():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/aggregated/insurance/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"transaction_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['transactionData']:
                    trans_name=i['name']
                    count=i['paymentInstruments'][0]['count']
                    amount=i['paymentInstruments'][0]['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["transaction_name"].append(trans_name)
                    column["count"].append(count)
                    column["amount"].append(amount)
    agg_ins_data=pd.DataFrame(column)
    agg_ins_data["state"].unique()
    agg_ins_data["state"]=agg_ins_data["state"].str.replace("-"," ")
    agg_ins_data["state"]=agg_ins_data["state"].str.title()
    agg_ins_data["state"]=agg_ins_data["state"].str.replace("&","and")

    agg_ins_table='''CREATE TABLE if not exists aggregated_insurance(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    Transaction_Name varchar(50),
                                                    Count bigint,
                                                    Amount bigint
                                                    )'''
    cursor.execute(agg_ins_table)
    connection.commit() 

    for index, row in agg_ins_data.iterrows():
        insert_query = '''INSERT INTO aggregated_insurance(State,Year,Quarter,Transaction_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['transaction_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()

    return agg_ins_data

def agg_trans():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/aggregated/transaction/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"transaction_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['transactionData']:
                    name=i['name']
                    count=i['paymentInstruments'][0]['count']
                    amount=i['paymentInstruments'][0]['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["transaction_name"].append(name)
                    column["count"].append(count)
                    column["amount"].append(amount)
    agg_trans_data=pd.DataFrame(column)
    agg_trans_data["state"].unique()
    agg_trans_data["state"]=agg_trans_data["state"].str.replace("-"," ")
    agg_trans_data["state"]=agg_trans_data["state"].str.title()
    agg_trans_data["state"]=agg_trans_data["state"].str.replace("&","and")
   

    agg_trans_table='''CREATE TABLE if not exists aggregated_transaction(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    Transaction_Name varchar(150),
                                                    Count bigint,
                                                    Amount bigint
                                                    )'''
    cursor.execute(agg_trans_table)
    connection.commit()

    for index, row in agg_trans_data.iterrows():
        insert_query = '''INSERT INTO aggregated_transaction(State,Year,Quarter,
                                                            Transaction_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['transaction_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()

    return agg_trans_data

def agg_user():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    
    path2="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/aggregated/user/country/india/state/"
    user_list=os.listdir(path2)
    columns={"state":[],"year":[],"quarter":[],"brand_name":[],"count":[],"percentage":[]}
    for state in user_list:
        state_link=path2+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                file=years_link+jsonfile
                data=open(file,"r")
                B=json.load(data)
                try:
                    for i in B['data']['usersByDevice']:
                        brand=i['brand']
                        count=i['count']
                        percentage=i['percentage']

                        columns["state"].append(state)
                        columns["year"].append(years)
                        columns["quarter"].append(int(jsonfile.strip(".json")))
                        columns["brand_name"].append(brand)
                        columns["count"].append(count)
                        columns["percentage"].append(percentage)
                except:
                    pass
    user_data=pd.DataFrame(columns)
    user_data["state"].unique()
    user_data["state"]=user_data["state"].str.replace("-"," ")
    user_data["state"]=user_data["state"].str.title()
    user_data["state"]=user_data["state"].str.replace("&","and")
    
    agg_user_table='''CREATE TABLE if not exists aggregated_user(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    Brand_Name varchar(150),
                                                    Count bigint,
                                                    Percentage FLOAT
                                                    )'''
    cursor.execute(agg_user_table)
    connection.commit()

    for index, row in user_data.iterrows():
        insert_query = '''INSERT INTO aggregated_user(State,Year,Quarter,
                                                            Brand_Name,Count,Percentage)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['brand_name'],
            row['count'],
            row['percentage']
        ))

    connection.commit()

    return user_data    


def map_insurance():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/map/insurance/hover/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"district_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['hoverDataList']:
                    dis_name=i['name']
                    count=i['metric'][0]['count']
                    amount=i['metric'][0]['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["district_name"].append(dis_name)
                    column["count"].append(count)
                    column["amount"].append(amount)
    map_ins_data=pd.DataFrame(column)
    map_ins_data["state"].unique()
    map_ins_data["state"]=map_ins_data["state"].str.replace("-"," ")
    map_ins_data["state"]=map_ins_data["state"].str.title()
    map_ins_data["state"]=map_ins_data["state"].str.replace("&","and")

    map_ins_table='''CREATE TABLE if not exists map_insurance(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    District_Name varchar(150),
                                                    Count bigint,
                                                    Amount bigint
                                                    )'''
    cursor.execute(map_ins_table)
    connection.commit()

    for index, row in map_ins_data.iterrows():
        insert_query = '''INSERT INTO map_insurance(State,Year,Quarter,
                                                            District_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['district_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()

    return map_ins_data

def map_trans():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/map/transaction/hover/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"district_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['hoverDataList']:
                    name=i['name']
                    count=i['metric'][0]['count']
                    amount=i['metric'][0]['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["district_name"].append(name)
                    column["count"].append(count)
                    column["amount"].append(amount)
    map_trans_data=pd.DataFrame(column)
    map_trans_data["state"].unique()
    map_trans_data["state"]=map_trans_data["state"].str.replace("-"," ")
    map_trans_data["state"]=map_trans_data["state"].str.title()
    map_trans_data["state"]=map_trans_data["state"].str.replace("&","and")
    
    map_trans_table='''CREATE TABLE if not exists map_transaction(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    District_Name varchar(150),
                                                    Count bigint,
                                                    Amount decimal(65,10)
                                                    )'''
    cursor.execute(map_trans_table)
    connection.commit()

    for index, row in map_trans_data.iterrows():
        insert_query = '''INSERT INTO map_transaction(State,Year,Quarter,
                                                            District_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['district_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()
    return map_trans_data

def map_users():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/map/user/hover/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"district_name":[],"registered_users":[],"app_opens":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['hoverData'].items():
                    dist_name=i[0]
                    reg_users=i[1]['registeredUsers']
                    app_opens=i[1]['appOpens']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["district_name"].append(dist_name)
                    column["registered_users"].append(reg_users)
                    column["app_opens"].append(app_opens)

    map_users_data=pd.DataFrame(column)
    map_users_data["state"].unique()
    map_users_data["state"]=map_users_data["state"].str.replace("-"," ")
    map_users_data["state"]=map_users_data["state"].str.title()
    map_users_data["state"]=map_users_data["state"].str.replace("&","and")

    map_users_table='''CREATE TABLE if not exists map_users(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    District_Name varchar(150),
                                                    Registered_Users bigint,
                                                    App_Opens bigint
                                                    )'''
    cursor.execute(map_users_table)
    connection.commit()
    

    for index, row in map_users_data.iterrows():
        insert_query = '''INSERT INTO map_users(State,Year,Quarter,
                                                            District_Name,Registered_Users,App_Opens)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['district_name'],
            row['registered_users'],
            row['app_opens']
        ))

    connection.commit()

    return map_users_data

def top_insurance():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()

    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/top/insurance/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"district_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['districts']:
                    entity_name=i['entityName']
                    count=i['metric']['count']
                    amount=i['metric']['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column['district_name'].append(entity_name)
                    column['count'].append(count)
                    column['amount'].append(amount)

    top_ins_data=pd.DataFrame(column)
    top_ins_data["state"].unique()
    top_ins_data["state"]=top_ins_data["state"].str.replace("-"," ")
    top_ins_data["state"]=top_ins_data["state"].str.title()
    top_ins_data["state"]=top_ins_data["state"].str.replace("&","and")

    top_ins_table='''CREATE TABLE if not exists top_insurance(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    District_Name varchar(50),
                                                    Count bigint,
                                                    Amount bigint
                                                    )'''
    cursor.execute(top_ins_table)
    connection.commit() 

    for index, row in top_ins_data.iterrows():
        insert_query = '''INSERT INTO top_insurance(State,Year,Quarter,District_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['district_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()
    return top_ins_data

def top_trans():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()

    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/top/transaction/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"district_name":[],"count":[],"amount":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)

                for i in A['data']['districts']:
                    entity_name=i['entityName']
                    count=i['metric']['count']
                    amount=i['metric']['amount']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column['district_name'].append(entity_name)
                    column['count'].append(count)
                    column['amount'].append(amount)

    top_trans_data=pd.DataFrame(column)
    top_trans_data["state"].unique()
    top_trans_data["state"]=top_trans_data["state"].str.replace("-"," ")
    top_trans_data["state"]=top_trans_data["state"].str.title()
    top_trans_data["state"]=top_trans_data["state"].str.replace("&","and")

    top_trans_table='''CREATE TABLE if not exists top_transaction(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    District_Name varchar(150),
                                                    Count bigint,
                                                    Amount decimal(65,10)
                                                    )'''
    cursor.execute(top_trans_table)
    connection.commit()

    for index, row in top_trans_data.iterrows():
        insert_query = '''INSERT INTO top_transaction(State,Year,Quarter,
                                                            District_Name,Count,Amount)
                          VALUES (%s, %s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['district_name'],
            row['count'],
            row['amount']
        ))

    connection.commit()
    return top_trans_data

def top_users():
    connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
    cursor=connection.cursor()
    path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/top/user/country/india/state/"
    path_list=os.listdir(path)
    column={"state":[],"year":[],"quarter":[],"pincodes":[],"registered_users":[]}
    for state in path_list:
        state_link=path+state+"/"
        state_list=os.listdir(state_link)
        for years in state_list:
            years_link=state_link+years+"/"
            years_list=os.listdir(years_link)
            for jsonfile in years_list:
                files=years_link+jsonfile
                data=open(files,"r")
                A=json.load(data)
                for i in A['data']['pincodes']:
                    name=i['name']
                    reg_users=i['registeredUsers']

                    column["state"].append(state)
                    column["year"].append(years)
                    column["quarter"].append(int(jsonfile.strip(".json")))
                    column["pincodes"].append(name)
                    column["registered_users"].append(reg_users)
    top_users_data=pd.DataFrame(column)
    top_users_data["state"].unique()
    top_users_data["state"]=top_users_data["state"].str.replace("-"," ")
    top_users_data["state"]=top_users_data["state"].str.title()
    top_users_data["state"]=top_users_data["state"].str.replace("&","and")

    top_users_table='''CREATE TABLE if not exists top_users(
                                                    State varchar(50),
                                                    Year int,
                                                    Quarter int,
                                                    Pincodes bigint,
                                                    Registered_Users bigint
                                                    )'''
    cursor.execute(top_users_table)
    connection.commit()
    

    for index, row in top_users_data.iterrows():
        insert_query = '''INSERT INTO top_users(State,Year,Quarter,
                                                            Pincodes,Registered_Users)
                          VALUES (%s, %s, %s, %s, %s)'''
        cursor.execute(insert_query, (
            row['state'],
            row['year'],
            row['quarter'],
            row['pincodes'],
            row['registered_users']
            
        ))
    connection.commit()
    
    return top_users_data

# %%
connection = mysql.connector.connect(
        user='root',
        password='mysql@123',
        database='Phonepay',
        host='localhost'
    )
cursor=connection.cursor()
#agg_ins_df
cursor.execute("SELECT * FROM aggregated_insurance")
table1=cursor.fetchall()
agg_ins_df=pd.DataFrame(table1,columns=("State","Year","Quarter","Transaction_Name","Count","Amount"))
connection.commit()
#agg_trans_df
cursor.execute("SELECT * FROM aggregated_transaction")
table2=cursor.fetchall()
agg_trans_df=pd.DataFrame(table2,columns=("State","Year","Quarter","Transaction_Name",
                                          "Count","Amount"))
connection.commit()
#agg_user_df
cursor.execute("SELECT * FROM aggregated_user")
table3=cursor.fetchall()
agg_user_df=pd.DataFrame(table3,columns=("State","Year","Quarter","Brand_Name","Count","Percentage"))
connection.commit()


#map_ins_df
cursor.execute("SELECT * FROM map_insurance")
table4=cursor.fetchall()
map_ins_df=pd.DataFrame(table4,columns=("State","Year","Quarter","District_Name","Count","Amount"))
connection.commit()
#map_trans_df
cursor.execute("SELECT * FROM map_transaction")
table5=cursor.fetchall()
map_trans_df=pd.DataFrame(table5,columns=("State","Year","Quarter","District_Name","Count","Amount"))
connection.commit()
#map_users_df
cursor.execute("SELECT * FROM map_users")
table6=cursor.fetchall()
map_users_df=pd.DataFrame(table6,columns=("State","Year","Quarter","District_Name","Registered_Users","App_Opens"))
connection.commit()

#top_ins_df
cursor.execute("SELECT * FROM top_insurance")
table7=cursor.fetchall()
top_ins_df=pd.DataFrame(table7,columns=("State","Year","Quarter","District_Name","Count","Amount"))
connection.commit()
#top_trans_df
cursor.execute("SELECT * FROM top_transaction")
table8=cursor.fetchall()
top_trans_df=pd.DataFrame(table8,columns=("State","Year","Quarter","District_Name","Count","Amount"))
connection.commit()
#top_users_df
cursor.execute("SELECT * FROM top_users")
table9=cursor.fetchall()
top_users_df=pd.DataFrame(table9,columns=("State","Year","Quarter","Pincodes","Registered_Users"))
connection.commit()

# %%
import os
import json
import pandas as pd
import mysql.connector

# %%
connection = mysql.connector.connect(
    user='root',
    password='mysql@123',
    database='Phonepay',
    host='localhost'
)
cursor=connection.cursor()

path="C:/Users/91822/OneDrive/Documents/Capstone-02/Capstone2/pulse/data/top/insurance/country/india/state/"
path_list=os.listdir(path)
column={"state":[],"year":[],"quarter":[],"district_name":[],"count":[],"amount":[]}
for state in path_list:
    state_link=path+state+"/"
    state_list=os.listdir(state_link)
    for years in state_list:
        years_link=state_link+years+"/"
        years_list=os.listdir(years_link)
        for jsonfile in years_list:
            files=years_link+jsonfile
            data=open(files,"r")
            A=json.load(data)
            for i in A['data']['districts']:
                print(i)
# Out:
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 3, 'amount': 565.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 3, 'amount': 795.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 35, 'amount': 13651.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 5, 'amount': 1448.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 1, 'amount': 281.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 109, 'amount': 137494.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 13, 'amount': 17734.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 2, 'amount': 2747.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 164, 'amount': 167044.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 48, 'amount': 63978.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 13, 'amount': 13244.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 105, 'amount': 121104.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 28, 'amount': 45311.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 4, 'amount': 15089.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 182, 'amount': 223699.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 33, 'amount': 50997.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 15, 'amount': 30539.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 632, 'amount': 800758.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 81, 'amount': 182061.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 44, 'amount': 73561.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 692, 'amount': 982206.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 48, 'amount': 85229.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 28, 'amount': 63852.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 430, 'amount': 633029.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 45, 'amount': 90403.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 26, 'amount': 56308.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 535, 'amount': 687813.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 70, 'amount': 129013.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 38, 'amount': 85640.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 750, 'amount': 1114857.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 112, 'amount': 224198.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 39, 'amount': 102155.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 872, 'amount': 1172083.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 85, 'amount': 178969.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 47, 'amount': 88146.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 670, 'amount': 1060976.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 56, 'amount': 109742.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 42, 'amount': 62677.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 682, 'amount': 1052324.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 77, 'amount': 133536.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 36, 'amount': 65285.0}}
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 1006, 'amount': 1504528.0}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 95, 'amount': 156995.0}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 44, 'amount': 96298.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 3504, 'amount': 614212.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 2739, 'amount': 485777.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 2698, 'amount': 475539.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 2228, 'amount': 395099.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 1978, 'amount': 343002.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 1938, 'amount': 344326.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 1913, 'amount': 352220.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 1074, 'amount': 202289.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 931, 'amount': 176423.0}}
# {'entityName': 'vizianagaram', 'metric': {'type': 'TOTAL', 'count': 893, 'amount': 166029.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 7906, 'amount': 1892376.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 5509, 'amount': 1259159.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 4519, 'amount': 1093882.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 4422, 'amount': 1178762.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 4230, 'amount': 1083584.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 3783, 'amount': 970549.0}}
# {'entityName': 'kurnool', 'metric': {'type': 'TOTAL', 'count': 3493, 'amount': 841970.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 3397, 'amount': 847519.0}}
# {'entityName': 'vizianagaram', 'metric': {'type': 'TOTAL', 'count': 2999, 'amount': 691281.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 2911, 'amount': 764850.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 3464, 'amount': 2203761.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 2570, 'amount': 1620649.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 2311, 'amount': 1222782.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 1965, 'amount': 1355741.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 1727, 'amount': 1168506.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 1534, 'amount': 794053.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 1390, 'amount': 906282.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 1348, 'amount': 810758.0}}
# {'entityName': 'prakasam', 'metric': {'type': 'TOTAL', 'count': 1190, 'amount': 572976.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 1165, 'amount': 631876.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 4006, 'amount': 2403199.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 2722, 'amount': 1699716.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 2412, 'amount': 1398326.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 1937, 'amount': 1065604.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 1629, 'amount': 1058050.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 1460, 'amount': 850251.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 1323, 'amount': 714947.0}}
# {'entityName': 'kurnool', 'metric': {'type': 'TOTAL', 'count': 1270, 'amount': 508161.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 1265, 'amount': 729565.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 1264, 'amount': 621128.0}}
# {'entityName': 'prakasam', 'metric': {'type': 'TOTAL', 'count': 5308, 'amount': 2719134.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 4655, 'amount': 3497573.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 4170, 'amount': 2327122.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 3451, 'amount': 2494257.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 2967, 'amount': 2201793.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 2392, 'amount': 1839579.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 2343, 'amount': 1695121.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 1817, 'amount': 1245872.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 1631, 'amount': 1284850.0}}
# {'entityName': 'kurnool', 'metric': {'type': 'TOTAL', 'count': 1410, 'amount': 941389.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 4044, 'amount': 3191769.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 3258, 'amount': 2722279.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 2519, 'amount': 2102143.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 2248, 'amount': 2073825.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 1991, 'amount': 1995617.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 1486, 'amount': 1161025.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 1452, 'amount': 1216098.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 1329, 'amount': 1311735.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 1137, 'amount': 1033282.0}}
# {'entityName': 'prakasam', 'metric': {'type': 'TOTAL', 'count': 1050, 'amount': 877683.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 4176, 'amount': 5425896.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 3029, 'amount': 3841028.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 2709, 'amount': 3214794.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 2532, 'amount': 3543718.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 2444, 'amount': 3100521.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 2369, 'amount': 2345876.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 1449, 'amount': 1479933.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 1322, 'amount': 2101400.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 1262, 'amount': 1853561.0}}
# {'entityName': 'prakasam', 'metric': {'type': 'TOTAL', 'count': 1181, 'amount': 1328774.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 5196, 'amount': 6953446.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 3914, 'amount': 5279784.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 3605, 'amount': 5199664.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 2887, 'amount': 4304499.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 2748, 'amount': 3988284.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 1991, 'amount': 3109555.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 1878, 'amount': 2608475.0}}
# {'entityName': 'prakasam', 'metric': {'type': 'TOTAL', 'count': 1797, 'amount': 2181402.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 1551, 'amount': 2556602.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 1439, 'amount': 2086496.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 5851, 'amount': 7046107.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 4578, 'amount': 5733009.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 3115, 'amount': 3979873.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 3103, 'amount': 3899091.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 2836, 'amount': 4207850.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 2141, 'amount': 2903957.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 2063, 'amount': 2686947.0}}
# {'entityName': 'prakasam', 'metric': {'type': 'TOTAL', 'count': 1962, 'amount': 2331922.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 1794, 'amount': 2729962.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 1418, 'amount': 1920103.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 6720, 'amount': 7779967.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 5529, 'amount': 6149431.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 4431, 'amount': 5271211.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 4355, 'amount': 5505134.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 3729, 'amount': 5145111.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 2593, 'amount': 3257610.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 2314, 'amount': 3113617.0}}
# {'entityName': 'prakasam', 'metric': {'type': 'TOTAL', 'count': 2137, 'amount': 2552054.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 1934, 'amount': 2719786.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 1892, 'amount': 2559169.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 7636, 'amount': 9911879.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 5484, 'amount': 6977122.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 5199, 'amount': 6244165.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 4641, 'amount': 6166050.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 4450, 'amount': 5856052.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 2733, 'amount': 3658896.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 2623, 'amount': 3513389.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 2425, 'amount': 3710468.0}}
# {'entityName': 'prakasam', 'metric': {'type': 'TOTAL', 'count': 2400, 'amount': 2848596.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 2261, 'amount': 2993022.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 6752, 'amount': 9502319.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 4693, 'amount': 6275818.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 4069, 'amount': 5915626.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 3542, 'amount': 4957590.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 3284, 'amount': 5677174.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 2461, 'amount': 3621734.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 2196, 'amount': 3370241.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 1565, 'amount': 2882540.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 1509, 'amount': 2235497.0}}
# {'entityName': 'prakasam', 'metric': {'type': 'TOTAL', 'count': 1437, 'amount': 2188369.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 7000, 'amount': 8910217.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 5163, 'amount': 6666796.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 3756, 'amount': 5988173.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 3725, 'amount': 5015442.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 3690, 'amount': 5519480.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 2468, 'amount': 3679371.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 2140, 'amount': 3383512.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 1688, 'amount': 3027497.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 1652, 'amount': 2426306.0}}
# {'entityName': 'kurnool', 'metric': {'type': 'TOTAL', 'count': 1473, 'amount': 2483871.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 8972, 'amount': 11107138.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 6187, 'amount': 7831756.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 4604, 'amount': 5810698.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 4157, 'amount': 5720660.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 3993, 'amount': 6350318.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 3082, 'amount': 3962298.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 2308, 'amount': 3162591.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 1947, 'amount': 3392196.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 1900, 'amount': 2732465.0}}
# {'entityName': 'kurnool', 'metric': {'type': 'TOTAL', 'count': 1723, 'amount': 2310997.0}}
# {'entityName': 'visakhapatnam', 'metric': {'type': 'TOTAL', 'count': 8787, 'amount': 12027284.0}}
# {'entityName': 'krishna', 'metric': {'type': 'TOTAL', 'count': 5268, 'amount': 7328216.0}}
# {'entityName': 'guntur', 'metric': {'type': 'TOTAL', 'count': 4354, 'amount': 6154821.0}}
# {'entityName': 'east godavari', 'metric': {'type': 'TOTAL', 'count': 4294, 'amount': 6404501.0}}
# {'entityName': 'chittoor', 'metric': {'type': 'TOTAL', 'count': 4025, 'amount': 7322967.0}}
# {'entityName': 'spsr nellore', 'metric': {'type': 'TOTAL', 'count': 2739, 'amount': 3968074.0}}
# {'entityName': 'west godavari', 'metric': {'type': 'TOTAL', 'count': 2198, 'amount': 3630998.0}}
# {'entityName': 'anantapur', 'metric': {'type': 'TOTAL', 'count': 2143, 'amount': 3651525.0}}
# {'entityName': 'ysr', 'metric': {'type': 'TOTAL', 'count': 1923, 'amount': 2738253.0}}
# {'entityName': 'kurnool', 'metric': {'type': 'TOTAL', 'count': 1829, 'amount': 3161720.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 33, 'amount': 6304.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 9, 'amount': 2511.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 5, 'amount': 1026.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 5, 'amount': 1124.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 3, 'amount': 827.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 2, 'amount': 469.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 2, 'amount': 513.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 2, 'amount': 513.0}}
# {'entityName': 'lower subansiri', 'metric': {'type': 'TOTAL', 'count': 1, 'amount': 231.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 1, 'amount': 231.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 60, 'amount': 15776.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 22, 'amount': 9675.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 12, 'amount': 3466.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 9, 'amount': 1557.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 5, 'amount': 2052.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 4, 'amount': 843.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 3, 'amount': 939.0}}
# {'entityName': 'dibang valley', 'metric': {'type': 'TOTAL', 'count': 3, 'amount': 66.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 3, 'amount': 1486.0}}
# {'entityName': 'east kameng', 'metric': {'type': 'TOTAL', 'count': 2, 'amount': 695.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 48, 'amount': 21298.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 15, 'amount': 22182.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 10, 'amount': 8075.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 10, 'amount': 9740.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 9, 'amount': 1981.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 7, 'amount': 5505.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 5, 'amount': 4148.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 4, 'amount': 1561.0}}
# {'entityName': 'lepa rada', 'metric': {'type': 'TOTAL', 'count': 3, 'amount': 2685.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 3, 'amount': 984.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 65, 'amount': 62651.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 18, 'amount': 8695.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 15, 'amount': 9871.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 12, 'amount': 4524.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 11, 'amount': 2951.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 11, 'amount': 10155.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 8, 'amount': 1248.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 7, 'amount': 3690.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 7, 'amount': 7696.0}}
# {'entityName': 'upper subansiri', 'metric': {'type': 'TOTAL', 'count': 7, 'amount': 4237.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 69, 'amount': 89335.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 20, 'amount': 17896.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 18, 'amount': 8990.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 16, 'amount': 21096.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 14, 'amount': 8091.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 13, 'amount': 23216.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 12, 'amount': 11258.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 11, 'amount': 8880.0}}
# {'entityName': 'lower subansiri', 'metric': {'type': 'TOTAL', 'count': 10, 'amount': 4236.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 6, 'amount': 2979.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 50, 'amount': 95368.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 23, 'amount': 32914.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 22, 'amount': 21566.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 21, 'amount': 57300.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 15, 'amount': 25894.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 15, 'amount': 35207.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 14, 'amount': 38082.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 13, 'amount': 11845.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 10, 'amount': 15097.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 8, 'amount': 5436.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 128, 'amount': 232985.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 37, 'amount': 61049.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 26, 'amount': 59532.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 17, 'amount': 19353.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 14, 'amount': 28772.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 14, 'amount': 37402.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 14, 'amount': 19295.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 14, 'amount': 25308.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 11, 'amount': 12440.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 7, 'amount': 22841.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 149, 'amount': 339981.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 36, 'amount': 83342.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 22, 'amount': 98280.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 22, 'amount': 50073.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 22, 'amount': 41022.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 17, 'amount': 33684.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 13, 'amount': 25903.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 11, 'amount': 59469.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 10, 'amount': 17012.0}}
# {'entityName': 'lower subansiri', 'metric': {'type': 'TOTAL', 'count': 9, 'amount': 27520.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 310, 'amount': 752159.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 47, 'amount': 115575.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 29, 'amount': 107087.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 26, 'amount': 61225.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 25, 'amount': 51823.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 24, 'amount': 54485.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 21, 'amount': 59273.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 15, 'amount': 32728.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 14, 'amount': 34582.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 13, 'amount': 25061.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 250, 'amount': 590296.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 42, 'amount': 118030.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 35, 'amount': 54567.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 24, 'amount': 112439.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 23, 'amount': 54004.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 22, 'amount': 53679.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 18, 'amount': 45865.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 17, 'amount': 26960.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 16, 'amount': 86941.0}}
# {'entityName': 'east kameng', 'metric': {'type': 'TOTAL', 'count': 15, 'amount': 25996.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 249, 'amount': 557453.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 53, 'amount': 140810.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 39, 'amount': 92295.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 35, 'amount': 74057.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 33, 'amount': 62867.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 32, 'amount': 117810.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 25, 'amount': 52176.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 23, 'amount': 56348.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 22, 'amount': 42902.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 22, 'amount': 69612.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 214, 'amount': 609907.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 58, 'amount': 150506.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 58, 'amount': 148766.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 45, 'amount': 131785.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 43, 'amount': 177062.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 26, 'amount': 77049.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 22, 'amount': 48743.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 20, 'amount': 42058.0}}
# {'entityName': 'lower subansiri', 'metric': {'type': 'TOTAL', 'count': 18, 'amount': 52453.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 17, 'amount': 32562.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 261, 'amount': 767297.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 87, 'amount': 278705.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 49, 'amount': 134410.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 48, 'amount': 182270.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 34, 'amount': 96483.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 31, 'amount': 117759.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 29, 'amount': 65934.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 29, 'amount': 51944.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 27, 'amount': 85810.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 21, 'amount': 70549.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 285, 'amount': 696186.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 65, 'amount': 185636.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 59, 'amount': 113780.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 44, 'amount': 108703.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 39, 'amount': 129855.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 39, 'amount': 140365.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 38, 'amount': 135660.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 34, 'amount': 55710.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 29, 'amount': 102043.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 23, 'amount': 92531.0}}
# {'entityName': 'papum pare', 'metric': {'type': 'TOTAL', 'count': 318, 'amount': 852980.0}}
# {'entityName': 'west kameng', 'metric': {'type': 'TOTAL', 'count': 67, 'amount': 190405.0}}
# {'entityName': 'namsai', 'metric': {'type': 'TOTAL', 'count': 49, 'amount': 120567.0}}
# {'entityName': 'west siang', 'metric': {'type': 'TOTAL', 'count': 48, 'amount': 119227.0}}
# {'entityName': 'changlang', 'metric': {'type': 'TOTAL', 'count': 47, 'amount': 94883.0}}
# {'entityName': 'tawang', 'metric': {'type': 'TOTAL', 'count': 45, 'amount': 167579.0}}
# {'entityName': 'east siang', 'metric': {'type': 'TOTAL', 'count': 42, 'amount': 109484.0}}
# {'entityName': 'lower dibang valley', 'metric': {'type': 'TOTAL', 'count': 35, 'amount': 81825.0}}
# {'entityName': 'lohit', 'metric': {'type': 'TOTAL', 'count': 34, 'amount': 77356.0}}
# {'entityName': 'tirap', 'metric': {'type': 'TOTAL', 'count': 32, 'amount': 74981.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 388, 'amount': 73071.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 52, 'amount': 11413.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 46, 'amount': 10879.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 41, 'amount': 8863.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 40, 'amount': 8918.0}}
# {'entityName': 'lakhimpur', 'metric': {'type': 'TOTAL', 'count': 34, 'amount': 7772.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 31, 'amount': 6886.0}}
# {'entityName': 'bongaigaon', 'metric': {'type': 'TOTAL', 'count': 30, 'amount': 6850.0}}
# {'entityName': 'karimganj', 'metric': {'type': 'TOTAL', 'count': 27, 'amount': 6710.0}}
# {'entityName': 'golaghat', 'metric': {'type': 'TOTAL', 'count': 25, 'amount': 5694.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 698, 'amount': 186125.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 111, 'amount': 29094.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 100, 'amount': 27927.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 98, 'amount': 28618.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 98, 'amount': 22486.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 95, 'amount': 28716.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 88, 'amount': 26070.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 82, 'amount': 25873.0}}
# {'entityName': 'bongaigaon', 'metric': {'type': 'TOTAL', 'count': 72, 'amount': 20029.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 62, 'amount': 19518.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 626, 'amount': 534531.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 147, 'amount': 104375.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 121, 'amount': 89658.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 121, 'amount': 110036.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 110, 'amount': 73472.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 101, 'amount': 76365.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 97, 'amount': 85549.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 91, 'amount': 63874.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 82, 'amount': 61112.0}}
# {'entityName': 'bongaigaon', 'metric': {'type': 'TOTAL', 'count': 69, 'amount': 45817.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 909, 'amount': 638404.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 162, 'amount': 151386.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 151, 'amount': 91536.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 138, 'amount': 94523.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 138, 'amount': 111672.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 137, 'amount': 97851.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 108, 'amount': 99440.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 91, 'amount': 81680.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 90, 'amount': 68041.0}}
# {'entityName': 'dhemaji', 'metric': {'type': 'TOTAL', 'count': 84, 'amount': 48008.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 910, 'amount': 790743.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 166, 'amount': 149754.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 150, 'amount': 166761.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 139, 'amount': 99192.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 138, 'amount': 138262.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 131, 'amount': 151795.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 125, 'amount': 110721.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 123, 'amount': 137739.0}}
# {'entityName': 'dhubri', 'metric': {'type': 'TOTAL', 'count': 92, 'amount': 89465.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 85, 'amount': 66263.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 1130, 'amount': 1219595.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 256, 'amount': 414468.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 254, 'amount': 379958.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 246, 'amount': 472172.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 244, 'amount': 369625.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 193, 'amount': 219360.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 187, 'amount': 191043.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 139, 'amount': 190170.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 121, 'amount': 187950.0}}
# {'entityName': 'baksa', 'metric': {'type': 'TOTAL', 'count': 120, 'amount': 133440.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 2250, 'amount': 2848340.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 470, 'amount': 805931.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 450, 'amount': 872663.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 422, 'amount': 720457.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 415, 'amount': 668817.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 376, 'amount': 622789.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 360, 'amount': 561224.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 322, 'amount': 545014.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 257, 'amount': 543440.0}}
# {'entityName': 'dhubri', 'metric': {'type': 'TOTAL', 'count': 255, 'amount': 370821.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 3580, 'amount': 5037571.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 873, 'amount': 1470129.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 865, 'amount': 1449243.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 841, 'amount': 1525020.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 746, 'amount': 1153589.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 735, 'amount': 1366384.0}}
# {'entityName': 'golaghat', 'metric': {'type': 'TOTAL', 'count': 651, 'amount': 1131690.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 643, 'amount': 1177509.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 594, 'amount': 1093901.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 530, 'amount': 905037.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 2330, 'amount': 3272854.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 587, 'amount': 1057176.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 552, 'amount': 928881.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 406, 'amount': 635248.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 406, 'amount': 598109.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 389, 'amount': 774583.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 385, 'amount': 680355.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 349, 'amount': 610793.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 347, 'amount': 575716.0}}
# {'entityName': 'kokrajhar', 'metric': {'type': 'TOTAL', 'count': 242, 'amount': 254646.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 3502, 'amount': 4613053.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 865, 'amount': 1425722.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 848, 'amount': 1381966.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 708, 'amount': 1128686.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 673, 'amount': 1113514.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 612, 'amount': 983523.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 566, 'amount': 936833.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 527, 'amount': 803800.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 472, 'amount': 803029.0}}
# {'entityName': 'karimganj', 'metric': {'type': 'TOTAL', 'count': 444, 'amount': 689445.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 5835, 'amount': 7067068.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 1095, 'amount': 1672604.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 1094, 'amount': 1961516.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 864, 'amount': 1321583.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 845, 'amount': 1263373.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 731, 'amount': 1242807.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 705, 'amount': 1215813.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 650, 'amount': 1190417.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 606, 'amount': 1014221.0}}
# {'entityName': 'lakhimpur', 'metric': {'type': 'TOTAL', 'count': 481, 'amount': 987421.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 5668, 'amount': 7671824.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 1255, 'amount': 2224803.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 1065, 'amount': 1974045.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 978, 'amount': 1827073.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 948, 'amount': 1554633.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 923, 'amount': 1577259.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 887, 'amount': 1574670.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 813, 'amount': 1490071.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 807, 'amount': 1506973.0}}
# {'entityName': 'lakhimpur', 'metric': {'type': 'TOTAL', 'count': 688, 'amount': 1386745.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 4012, 'amount': 5898627.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 1121, 'amount': 2142408.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 893, 'amount': 1605940.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 767, 'amount': 1428414.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 690, 'amount': 1153785.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 683, 'amount': 1025061.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 656, 'amount': 1133925.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 641, 'amount': 1239379.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 581, 'amount': 1111680.0}}
# {'entityName': 'lakhimpur', 'metric': {'type': 'TOTAL', 'count': 574, 'amount': 1175317.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 4860, 'amount': 6709390.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 1582, 'amount': 2574384.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 1229, 'amount': 1769686.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 1173, 'amount': 1931012.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 1077, 'amount': 1850471.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 1072, 'amount': 1795306.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 927, 'amount': 1535288.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 842, 'amount': 1278019.0}}
# {'entityName': 'lakhimpur', 'metric': {'type': 'TOTAL', 'count': 710, 'amount': 1288953.0}}
# {'entityName': 'dhubri', 'metric': {'type': 'TOTAL', 'count': 699, 'amount': 1028552.0}}
# {'entityName': 'kamrup metropolitan', 'metric': {'type': 'TOTAL', 'count': 5317, 'amount': 7719481.0}}
# {'entityName': 'sonitpur', 'metric': {'type': 'TOTAL', 'count': 1353, 'amount': 2337321.0}}
# {'entityName': 'dibrugarh', 'metric': {'type': 'TOTAL', 'count': 1311, 'amount': 2554356.0}}
# {'entityName': 'barpeta', 'metric': {'type': 'TOTAL', 'count': 1163, 'amount': 1993408.0}}
# {'entityName': 'kamrup', 'metric': {'type': 'TOTAL', 'count': 1106, 'amount': 1685946.0}}
# {'entityName': 'nagaon', 'metric': {'type': 'TOTAL', 'count': 1095, 'amount': 1810718.0}}
# {'entityName': 'jorhat', 'metric': {'type': 'TOTAL', 'count': 963, 'amount': 1550776.0}}
# {'entityName': 'tinsukia', 'metric': {'type': 'TOTAL', 'count': 899, 'amount': 1734025.0}}
# {'entityName': 'dhubri', 'metric': {'type': 'TOTAL', 'count': 755, 'amount': 1083292.0}}
# {'entityName': 'cachar', 'metric': {'type': 'TOTAL', 'count': 737, 'amount': 1308876.0}}
# {'entityName': 'patna', 'metric': {'type': 'TOTAL', 'count': 685, 'amount': 126689.0}}
# {'entityName': 'begusarai', 'metric': {'type': 'TOTAL', 'count': 158, 'amount': 31671.0}}
# {'entityName': 'muzaffarpur', 'metric': {'type': 'TOTAL', 'count': 132, 'amount': 28803.0}}
# {'entityName': 'gaya', 'metric': {'type': 'TOTAL', 'count': 117, 'amount': 24619.0}}
# {'entityName': 'darbhanga', 'metric': {'type': 'TOTAL', 'count': 103, 'amount': 21997.0}}
# {'entityName': 'purbi champaran', 'metric': {'type': 'TOTAL', 'count': 100, 'amount': 22466.0}}
# {'entityName': 'bhagalpur', 'metric': {'type': 'TOTAL', 'count': 96, 'amount': 22602.0}}
# {'entityName': 'pashchim champaran', 'metric': {'type': 'TOTAL', 'count': 92, 'amount': 20072.0}}
# {'entityName': 'madhubani', 'metric': {'type': 'TOTAL', 'count': 89, 'amount': 19995.0}}
# {'entityName': 'vaishali', 'metric': {'type': 'TOTAL', 'count': 86, 'amount': 20680.0}}
# {'entityName': 'patna', 'metric': {'type': 'TOTAL', 'count': 1926, 'amount': 427322.0}}
# {'entityName': 'muzaffarpur', 'metric': {'type': 'TOTAL', 'count': 752, 'amount': 179003.0}}
# {'entityName': 'purbi champaran', 'metric': {'type': 'TOTAL', 'count': 497, 'amount': 111197.0}}
# {'entityName': 'gaya', 'metric': {'type': 'TOTAL', 'count': 408, 'amount': 85332.0}}
# {'entityName': 'vaishali', 'metric': {'type': 'TOTAL', 'count': 408, 'amount': 89031.0}}
# {'entityName': 'samastipur', 'metric': {'type': 'TOTAL', 'count': 344, 'amount': 81819.0}}
# {'entityName': 'darbhanga', 'metric': {'type': 'TOTAL', 'count': 325, 'amount': 73191.0}}
# {'entityName': 'bhagalpur', 'metric': {'type': 'TOTAL', 'count': 325, 'amount': 80091.0}}
# {'entityName': 'saran', 'metric': {'type': 'TOTAL', 'count': 323, 'amount': 78623.0}}
# {'entityName': 'purnia', 'metric': {'type': 'TOTAL', 'count': 292, 'amount': 61193.0}}
# {'entityName': 'patna', 'metric': {'type': 'TOTAL', 'count': 1831, 'amount': 1396144.0}}
# {'entityName': 'muzaffarpur', 'metric': {'type': 'TOTAL', 'count': 616, 'amount': 462851.0}}
# {'entityName': 'vaishali', 'metric': {'type': 'TOTAL', 'count': 445, 'amount': 381786.0}}
# {'entityName': 'saran', 'metric': {'type': 'TOTAL', 'count': 410, 'amount': 376021.0}}
# {'entityName': 'samastipur', 'metric': {'type': 'TOTAL', 'count': 404, 'amount': 405354.0}}
# {'entityName': 'darbhanga', 'metric': {'type': 'TOTAL', 'count': 375, 'amount': 329076.0}}
# {'entityName': 'gaya', 'metric': {'type': 'TOTAL', 'count': 366, 'amount': 260585.0}}
# {'entityName': 'madhubani', 'metric': {'type': 'TOTAL', 'count': 362, 'amount': 312107.0}}
# {'entityName': 'purbi champaran', 'metric': {'type': 'TOTAL', 'count': 336, 'amount': 195193.0}}
# {'entityName': 'bhagalpur', 'metric': {'type': 'TOTAL', 'count': 332, 'amount': 281912.0}}
# {'entityName': 'patna', 'metric': {'type': 'TOTAL', 'count': 2101, 'amount': 1349311.0}}
# {'entityName': 'muzaffarpur', 'metric': {'type': 'TOTAL', 'count': 750, 'amount': 518615.0}}
# ...
# {'entityName': 'pauri garhwal', 'metric': {'type': 'TOTAL', 'count': 466, 'amount': 723598.0}}
# {'entityName': 'pithoragarh', 'metric': {'type': 'TOTAL', 'count': 259, 'amount': 463687.0}}
# {'entityName': 'almora', 'metric': {'type': 'TOTAL', 'count': 238, 'amount': 427365.0}}
# {'entityName': 'tehri garhwal', 'metric': {'type': 'TOTAL', 'count': 187, 'amount': 379190.0}}
# {'entityName': 'chamoli', 'metric': {'type': 'TOTAL', 'count': 120, 'amount': 262413.0}}
# {'entityName': 'champawat', 'metric': {'type': 'TOTAL', 'count': 111, 'amount': 175544.0}}
# {'entityName': 'dehradun', 'metric': {'type': 'TOTAL', 'count': 3417, 'amount': 6454643.0}}
# {'entityName': 'haridwar', 'metric': {'type': 'TOTAL', 'count': 1693, 'amount': 3183018.0}}
# {'entityName': 'udham singh nagar', 'metric': {'type': 'TOTAL', 'count': 1667, 'amount': 3091689.0}}
# {'entityName': 'nainital', 'metric': {'type': 'TOTAL', 'count': 1086, 'amount': 1911707.0}}
# {'entityName': 'pauri garhwal', 'metric': {'type': 'TOTAL', 'count': 592, 'amount': 1037849.0}}
# {'entityName': 'tehri garhwal', 'metric': {'type': 'TOTAL', 'count': 320, 'amount': 700351.0}}
# {'entityName': 'almora', 'metric': {'type': 'TOTAL', 'count': 278, 'amount': 589368.0}}
# {'entityName': 'pithoragarh', 'metric': {'type': 'TOTAL', 'count': 274, 'amount': 554770.0}}
# {'entityName': 'chamoli', 'metric': {'type': 'TOTAL', 'count': 232, 'amount': 619715.0}}
# {'entityName': 'champawat', 'metric': {'type': 'TOTAL', 'count': 154, 'amount': 266866.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 2047, 'amount': 355405.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 1288, 'amount': 224075.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 631, 'amount': 114387.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 565, 'amount': 108804.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 502, 'amount': 100403.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 351, 'amount': 71221.0}}
# {'entityName': 'nadia', 'metric': {'type': 'TOTAL', 'count': 317, 'amount': 61692.0}}
# {'entityName': 'purba medinipur', 'metric': {'type': 'TOTAL', 'count': 274, 'amount': 56622.0}}
# {'entityName': 'paschim medinipur', 'metric': {'type': 'TOTAL', 'count': 270, 'amount': 56494.0}}
# {'entityName': 'darjiling', 'metric': {'type': 'TOTAL', 'count': 247, 'amount': 45481.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 2689, 'amount': 617166.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 1833, 'amount': 435620.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 847, 'amount': 201886.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 846, 'amount': 181661.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 774, 'amount': 175635.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 757, 'amount': 186165.0}}
# {'entityName': 'purba medinipur', 'metric': {'type': 'TOTAL', 'count': 581, 'amount': 142104.0}}
# {'entityName': 'paschim medinipur', 'metric': {'type': 'TOTAL', 'count': 564, 'amount': 133265.0}}
# {'entityName': 'nadia', 'metric': {'type': 'TOTAL', 'count': 521, 'amount': 110858.0}}
# {'entityName': 'murshidabad', 'metric': {'type': 'TOTAL', 'count': 458, 'amount': 86182.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 1914, 'amount': 1511195.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 1692, 'amount': 1306337.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 713, 'amount': 547727.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 607, 'amount': 550802.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 569, 'amount': 439509.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 563, 'amount': 397183.0}}
# {'entityName': 'purba medinipur', 'metric': {'type': 'TOTAL', 'count': 439, 'amount': 271897.0}}
# {'entityName': 'murshidabad', 'metric': {'type': 'TOTAL', 'count': 422, 'amount': 213072.0}}
# {'entityName': 'nadia', 'metric': {'type': 'TOTAL', 'count': 380, 'amount': 251150.0}}
# {'entityName': 'koch bihar', 'metric': {'type': 'TOTAL', 'count': 379, 'amount': 275427.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 3750, 'amount': 2611912.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 2388, 'amount': 2089048.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 1354, 'amount': 871815.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 892, 'amount': 679890.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 759, 'amount': 588011.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 609, 'amount': 470478.0}}
# {'entityName': 'maldah', 'metric': {'type': 'TOTAL', 'count': 560, 'amount': 326652.0}}
# {'entityName': 'darjiling', 'metric': {'type': 'TOTAL', 'count': 549, 'amount': 528296.0}}
# {'entityName': 'paschim medinipur', 'metric': {'type': 'TOTAL', 'count': 530, 'amount': 335241.0}}
# {'entityName': 'murshidabad', 'metric': {'type': 'TOTAL', 'count': 520, 'amount': 331408.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 3025, 'amount': 2628371.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 2513, 'amount': 1919618.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 1814, 'amount': 1161847.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 969, 'amount': 839685.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 864, 'amount': 813571.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 697, 'amount': 653764.0}}
# {'entityName': 'purba bardhaman', 'metric': {'type': 'TOTAL', 'count': 596, 'amount': 531232.0}}
# {'entityName': 'nadia', 'metric': {'type': 'TOTAL', 'count': 535, 'amount': 465213.0}}
# {'entityName': 'purba medinipur', 'metric': {'type': 'TOTAL', 'count': 506, 'amount': 346436.0}}
# {'entityName': 'darjiling', 'metric': {'type': 'TOTAL', 'count': 489, 'amount': 422426.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 4808, 'amount': 3468389.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 4077, 'amount': 3664190.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 2972, 'amount': 1791035.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 1702, 'amount': 1365468.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 1342, 'amount': 1446109.0}}
# {'entityName': 'purba bardhaman', 'metric': {'type': 'TOTAL', 'count': 1246, 'amount': 1113357.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 1104, 'amount': 1186714.0}}
# {'entityName': 'maldah', 'metric': {'type': 'TOTAL', 'count': 1082, 'amount': 917118.0}}
# {'entityName': 'darjiling', 'metric': {'type': 'TOTAL', 'count': 851, 'amount': 790413.0}}
# {'entityName': 'koch bihar', 'metric': {'type': 'TOTAL', 'count': 743, 'amount': 505542.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 4922, 'amount': 5698422.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 4645, 'amount': 4777380.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 1957, 'amount': 2162907.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 1781, 'amount': 2143612.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 1751, 'amount': 1907817.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 1509, 'amount': 1862383.0}}
# {'entityName': 'maldah', 'metric': {'type': 'TOTAL', 'count': 1208, 'amount': 1432474.0}}
# {'entityName': 'darjiling', 'metric': {'type': 'TOTAL', 'count': 1070, 'amount': 1346165.0}}
# {'entityName': 'purba bardhaman', 'metric': {'type': 'TOTAL', 'count': 1047, 'amount': 1172623.0}}
# {'entityName': 'paschim medinipur', 'metric': {'type': 'TOTAL', 'count': 1019, 'amount': 1473713.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 6763, 'amount': 7736401.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 6640, 'amount': 8833426.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 2597, 'amount': 3174912.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 2553, 'amount': 3584327.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 2161, 'amount': 3005032.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 1915, 'amount': 2609225.0}}
# {'entityName': 'maldah', 'metric': {'type': 'TOTAL', 'count': 1876, 'amount': 2421056.0}}
# {'entityName': 'paschim medinipur', 'metric': {'type': 'TOTAL', 'count': 1780, 'amount': 2355975.0}}
# {'entityName': 'purba bardhaman', 'metric': {'type': 'TOTAL', 'count': 1738, 'amount': 2221947.0}}
# {'entityName': 'darjiling', 'metric': {'type': 'TOTAL', 'count': 1572, 'amount': 1998293.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 6379, 'amount': 8088304.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 6127, 'amount': 6704205.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 2367, 'amount': 2846008.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 2163, 'amount': 2809645.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 1807, 'amount': 2478141.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 1804, 'amount': 2479308.0}}
# {'entityName': 'darjiling', 'metric': {'type': 'TOTAL', 'count': 1351, 'amount': 1706036.0}}
# {'entityName': 'purba bardhaman', 'metric': {'type': 'TOTAL', 'count': 1284, 'amount': 1606058.0}}
# {'entityName': 'paschim medinipur', 'metric': {'type': 'TOTAL', 'count': 1273, 'amount': 1512137.0}}
# {'entityName': 'nadia', 'metric': {'type': 'TOTAL', 'count': 1189, 'amount': 1690781.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 8821, 'amount': 10908223.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 8666, 'amount': 9648958.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 3388, 'amount': 4205397.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 3386, 'amount': 3925097.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 2688, 'amount': 3490145.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 2535, 'amount': 3346651.0}}
# {'entityName': 'purba bardhaman', 'metric': {'type': 'TOTAL', 'count': 2079, 'amount': 2560858.0}}
# {'entityName': 'maldah', 'metric': {'type': 'TOTAL', 'count': 1776, 'amount': 2288540.0}}
# {'entityName': 'nadia', 'metric': {'type': 'TOTAL', 'count': 1754, 'amount': 2454885.0}}
# {'entityName': 'paschim medinipur', 'metric': {'type': 'TOTAL', 'count': 1733, 'amount': 2279289.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 10071, 'amount': 13297497.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 9215, 'amount': 10683722.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 3875, 'amount': 4827100.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 3847, 'amount': 4752290.0}}
# {'entityName': 'paschim medinipur', 'metric': {'type': 'TOTAL', 'count': 3569, 'amount': 4249681.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 3046, 'amount': 4171226.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 2783, 'amount': 3954761.0}}
# {'entityName': 'darjiling', 'metric': {'type': 'TOTAL', 'count': 2351, 'amount': 3298987.0}}
# {'entityName': 'maldah', 'metric': {'type': 'TOTAL', 'count': 2002, 'amount': 2670979.0}}
# {'entityName': 'nadia', 'metric': {'type': 'TOTAL', 'count': 1870, 'amount': 2669178.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 11211, 'amount': 15232572.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 10117, 'amount': 12593112.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 4051, 'amount': 5337244.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 3767, 'amount': 5042986.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 3264, 'amount': 4547900.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 3076, 'amount': 4353663.0}}
# {'entityName': 'paschim medinipur', 'metric': {'type': 'TOTAL', 'count': 2443, 'amount': 3304941.0}}
# {'entityName': 'maldah', 'metric': {'type': 'TOTAL', 'count': 2438, 'amount': 3326078.0}}
# {'entityName': 'darjiling', 'metric': {'type': 'TOTAL', 'count': 2218, 'amount': 3099342.0}}
# {'entityName': 'nadia', 'metric': {'type': 'TOTAL', 'count': 2212, 'amount': 3033002.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 9956, 'amount': 12796714.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 9018, 'amount': 11042108.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 3576, 'amount': 4536325.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 3369, 'amount': 4382040.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 2918, 'amount': 3955797.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 2861, 'amount': 3933669.0}}
# {'entityName': 'darjiling', 'metric': {'type': 'TOTAL', 'count': 2037, 'amount': 2825313.0}}
# {'entityName': 'nadia', 'metric': {'type': 'TOTAL', 'count': 2021, 'amount': 2682343.0}}
# {'entityName': 'paschim medinipur', 'metric': {'type': 'TOTAL', 'count': 1804, 'amount': 2352680.0}}
# {'entityName': 'maldah', 'metric': {'type': 'TOTAL', 'count': 1799, 'amount': 2468202.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 11653, 'amount': 15397844.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 10667, 'amount': 12579074.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 4100, 'amount': 5345416.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 3960, 'amount': 4940209.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 3336, 'amount': 4705529.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 3285, 'amount': 4337285.0}}
# {'entityName': 'purba bardhaman', 'metric': {'type': 'TOTAL', 'count': 2444, 'amount': 3247192.0}}
# {'entityName': 'darjiling', 'metric': {'type': 'TOTAL', 'count': 2298, 'amount': 3188462.0}}
# {'entityName': 'maldah', 'metric': {'type': 'TOTAL', 'count': 2131, 'amount': 2771850.0}}
# {'entityName': 'paschim medinipur', 'metric': {'type': 'TOTAL', 'count': 2108, 'amount': 3021797.0}}
# {'entityName': 'north twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 13483, 'amount': 19211808.0}}
# {'entityName': 'kolkata', 'metric': {'type': 'TOTAL', 'count': 12306, 'amount': 16022532.0}}
# {'entityName': 'south twenty four parganas', 'metric': {'type': 'TOTAL', 'count': 5415, 'amount': 6996283.0}}
# {'entityName': 'howrah', 'metric': {'type': 'TOTAL', 'count': 5201, 'amount': 6655473.0}}
# {'entityName': 'paschim bardhaman', 'metric': {'type': 'TOTAL', 'count': 4095, 'amount': 5823988.0}}
# {'entityName': 'hooghly', 'metric': {'type': 'TOTAL', 'count': 4025, 'amount': 5665468.0}}
# {'entityName': 'paschim medinipur', 'metric': {'type': 'TOTAL', 'count': 3442, 'amount': 4688055.0}}
# {'entityName': 'maldah', 'metric': {'type': 'TOTAL', 'count': 2886, 'amount': 3998317.0}}
# {'entityName': 'nadia', 'metric': {'type': 'TOTAL', 'count': 2786, 'amount': 4012958.0}}
# {'entityName': 'darjiling', 'metric': {'type': 'TOTAL', 'count': 2762, 'amount': 4044883.0}}

# %%
pip install --upgrade nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\91822\onedrive\documents\capstone-02\capstone2\venv\lib\site-packages (5.9.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: fastjsonschema in c:\users\91822\onedrive\documents\capstone-02\capstone2\venv\lib\site-packages (from nbformat) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\91822\onedrive\documents\capstone-02\capstone2\venv\lib\site-packages (from nbformat) (4.21.1)
# Requirement already satisfied: jupyter-core in c:\users\91822\onedrive\documents\capstone-02\capstone2\venv\lib\site-packages (from nbformat) (5.7.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\91822\onedrive\documents\capstone-02\capstone2\venv\lib\site-packages (from nbformat) (5.14.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\91822\onedrive\documents\capstone-02\capstone2\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\91822\onedrive\documents\capstone-02\capstone2\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\91822\onedrive\documents\capstone-02\capstone2\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\91822\onedrive\documents\capstone-02\capstone2\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\91822\onedrive\documents\capstone-02\capstone2\venv\lib\site-packages (from jupyter-core->nbformat) (4.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\91822\onedrive\documents\capstone-02\capstone2\venv\lib\site-packages (from jupyter-core->nbformat) (306)
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
sql_query = "SELECT SUM(Transaction_Amount) AS Total_Amount FROM aggregated_transaction"
cursor.execute(sql_query)
total_amount_row = cursor.fetchone()
total_amount = total_amount_row[0]
total_amount_float = float(total_amount)
total_amount_crores = np.round(total_amount_float / 10_000_000,2)
print('Total Payment Value: ' + str(total_amount_crores) + ' Crores')
# Out:
# Total Payment Value: 21589774.15 Crores

# %%
def map_quarter_to_numeric(quarter):
    quarter_mapping = {1: "Q1", 2: "Q2", 3: "Q3", 4: "Q4"}
    return quarter_mapping[quarter]
